# %% [markdown]
# #  **Business Problem** #

# %% [markdown]
#   New Orleans is a city of culture and food. A recent entrepreneur wants to open an Ethiopian restaurant somewhere in the New Orleans area and would like some suggestions on different neighborhoods that may be a good fit. We can cluster the neighborhoods based off of nearby venues and use the customer’s business plan to make an informed decision
#    - Does she want to be the local stop in a mostly residential area?
#    - Does she want to be in the hustle of a crowded but potentially profitable entertainment district?
#    - Does she want to be a lunch spot for office workers located close buy?
#
# Hopefully the data will give us insight.
#    For this activity we will use a New Orleans neighborhood table from this wikipedia page to plot different neighborhoods (https://en.wikipedia.org/wiki/Neighborhoods_in_New_Orleans). From there I will use the Foursquare API to get a list of venues in the area. We will then cluster the neighborhoods based off of those venues.
#
#    Finally we can look at the clusters and help the entrepreneur pick a location depending on his desired market.
#    - Does she want to be the local stop in a mostly residential area?
#    - Does she want to be in the hustle of a crowded but potentially profitable entertainment district?
#    - Does she want to be a lunch spot for office workers located close buy?
#
# Hopefully the data will help us come to a decision.
